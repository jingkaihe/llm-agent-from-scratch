# %% [markdown]
# The core loop: need to tell user that they need to input exit if they want to stop the loop, and if they do not stop the loop, the scripts below cannot be execute.
#
# Maybe reanme HAL with "Agent Bob"
#
# Put this line "Also don't worry if you can't understand what this function does. Just use this as a utility" at the begining of the "The Tool System" section
